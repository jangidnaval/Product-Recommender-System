# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame 
import nltk

from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
import re

import string
#from wordcloud import WordCloud, STOPWORDS
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('../csv/product_product.csv')

# %%
df.describe()
# Out:
#              overall          count
# count  346355.000000  346355.000000
# mean        4.274958      19.536493
# std         1.120213      28.546791
# min         1.000000       5.000000
# 25%         4.000000       6.000000
# 50%         5.000000      10.000000
# 75%         5.000000      20.000000
# max         5.000000    1089.000000

# %%
def min_reviews_req(df):
    x=df.describe()
    min_count=x.loc['50%','count']
    #considering top 50% products by reviews count......
    new_df=df[df['count']>=min_count]
    return new_df

# %%
new_df=min_reviews_req(df)

# %%
new_df.index.size
# Out:
# 181489

# %%
new_df.head()
# Out:
#               asin                                 summary  overall  count
# 164866  B002DWA2H4                    med cabinet standard        5     10
# 164867  B002DWA2H4  So glad the ban on Excedrin was lifted        4     10
# 164868  B002DWA2H4                                my go to        5     10
# 164869  B002DWA2H4                         My old stand-by        5     10
# 164870  B002DWA2H4         Nothing better for my headaches        5     10

# %%
new_df.describe()
# Out:
#              overall          count
# count  181489.000000  181489.000000
# mean        4.273548      31.369185
# std         1.103638      35.486832
# min         1.000000      10.000000
# 25%         4.000000      13.000000
# 50%         5.000000      19.000000
# 75%         5.000000      37.000000
# max         5.000000    1089.000000

# %%
dfProductReview=new_df.groupby("asin", as_index=False).mean()

# %%
dfProductReview.asin.unique().size
# Out:
# 9234

# %%
ProductReviewSummary = new_df.groupby("asin")["summary"].apply(list)
ProductReviewSummary = pd.DataFrame(ProductReviewSummary)
ProductReviewSummary.reset_index(inplace=True)

# %%
ProductReviewSummary.head()
# Out:
#          asin                                            summary
# 0  B002DWA2H4  [med cabinet standard, So glad the ban on Exce...
# 1  B002DWA3AA  [Palatable, Tasty and helpful, Not perfect but...
# 2  B002DXZIOU  [Nice, Great, Good product, bad packaging, I d...
# 3  B002DYIZIU  [No Rush But Certainly Helpful, Need Your BCAA...
# 4  B002DYIZO4  [Flavored Beta-Alanine, WHAT?!, Beta Alanine (...

# %%
ProductReviewSummary.to_csv("../csv/ProductReviewSummary.csv",index=False)

# %%
ProductReviewSummary=pd.read_csv("../csv/ProductReviewSummary.csv")

# %%
ProductReviewSummary.head()
# Out:
#          asin                                            summary
# 0  B002DWA2H4  ['med cabinet standard', 'So glad the ban on E...
# 1  B002DWA3AA  ['Palatable', 'Tasty and helpful', 'Not perfec...
# 2  B002DXZIOU  ['Nice', 'Great', 'Good product, bad packaging...
# 3  B002DYIZIU  ['No Rush But Certainly Helpful', 'Need Your B...
# 4  B002DYIZO4  ['Flavored Beta-Alanine, WHAT?!', 'Beta Alanin...

# %%
dfMerged=pd.merge(ProductReviewSummary,dfProductReview,on='asin')

# %%
dfMerged.drop('count',inplace=True,axis=1)

# %%
dfMerged.head()
# Out:
#          asin                                            summary   overall
# 0  B002DWA2H4  ['med cabinet standard', 'So glad the ban on E...  4.888889
# 1  B002DWA3AA  ['Palatable', 'Tasty and helpful', 'Not perfec...  4.437500
# 2  B002DXZIOU  ['Nice', 'Great', 'Good product, bad packaging...  4.214286
# 3  B002DYIZIU  ['No Rush But Certainly Helpful', 'Need Your B...  4.022727
# 4  B002DYIZO4  ['Flavored Beta-Alanine, WHAT?!', 'Beta Alanin...  5.000000

# %% [markdown]
# # Text Cleaning - Summary column

# %%
#function for tokenizing summary
regEx = re.compile('[^a-z]+')
def cleanReviews(reviewText):
    reviewText = str.lower(reviewText)
    reviewText = regEx.sub(' ', reviewText).strip()
    return reviewText

# %%
dfMerged.head()
# Out:
#          asin                                            summary   overall
# 0  B002DWA2H4  ['med cabinet standard', 'So glad the ban on E...  4.888889
# 1  B002DWA3AA  ['Palatable', 'Tasty and helpful', 'Not perfec...  4.437500
# 2  B002DXZIOU  ['Nice', 'Great', 'Good product, bad packaging...  4.214286
# 3  B002DYIZIU  ['No Rush But Certainly Helpful', 'Need Your B...  4.022727
# 4  B002DYIZO4  ['Flavored Beta-Alanine, WHAT?!', 'Beta Alanin...  5.000000

# %%
#reset index and drop duplicate rows
dfMerged['clean_summary'] = dfMerged['summary'].apply(lambda x:cleanReviews(x))
#dfMerged = dfMerged.drop_duplicates(['overall'], keep='last')
#dfMerged = dfMerged.reset_index()

# %%
dfMerged.index.size
# Out:
# 9234

# %%
dfMerged.head()
# Out:
#          asin                                            summary   overall  \
# 0  B002DWA2H4  ['med cabinet standard', 'So glad the ban on E...  4.888889
# 1  B002DWA3AA  ['Palatable', 'Tasty and helpful', 'Not perfec...  4.437500
# 2  B002DXZIOU  ['Nice', 'Great', 'Good product, bad packaging...  4.214286
# 3  B002DYIZIU  ['No Rush But Certainly Helpful', 'Need Your B...  4.022727
# 4  B002DYIZO4  ['Flavored Beta-Alanine, WHAT?!', 'Beta Alanin...  5.000000
#
#                                        clean_summary
# 0  med cabinet standard so glad the ban on excedr...
# 1  palatable tasty and helpful not perfect but cl...
# 2  nice great good product bad packaging i don t ...
# 3  no rush but certainly helpful need your bcaas ...
# 4  flavored beta alanine what beta alanine bka th...

# %%
reviews = dfMerged["clean_summary"] 
countVector = CountVectorizer(max_features = 400, stop_words='english') 
transformedReviews = countVector.fit_transform(reviews)

# %%
transformedReviews.A
#print(transformedReviews)
dfReviews = DataFrame(transformedReviews.A, columns=countVector.get_feature_names())
dfReviews = dfReviews.astype(int)

# %%
product_id=pd.DataFrame()
product_id[['asin','overall']]=dfMerged[['asin','overall']]

# %%
product_id.to_csv("../csv/product_id.csv",index=False,sep=',')

# %%
product_id=pd.read_csv("../csv/product_id.csv")

# %%
product_id.head()
# Out:
#          asin   overall
# 0  B002DWA2H4  4.888889
# 1  B002DWA3AA  4.437500
# 2  B002DXZIOU  4.214286
# 3  B002DYIZIU  4.022727
# 4  B002DYIZO4  5.000000

# %%
dfReviews=product_id.join(dfReviews)

# %%
#save 
dfReviews.to_csv("../csv/Summary_Feature.csv",index=False)

# %%
dfReviews=pd.read_csv("../csv/Summary_Feature.csv")

# %%
#test train spilt.....
train,test=train_test_split(dfReviews,test_size=0.3)
print("Train sample size ",train.index.size)
print("Test sample size ",test.index.size)

train_features=train.drop(['asin','overall'],axis=1)
test_features=test.drop(['asin','overall'],axis=1)
           
train_array=np.array(train_features)
test_array=np.array(test_features)
# Out:
# Train sample size  6463
# Test sample size  2771

# %%
train.to_csv('../csv/train.csv',index=False)
test.to_csv('../csv/test.csv',index=False)

# %%
neighbor = NearestNeighbors(n_neighbors=3, algorithm='ball_tree')
neighbor.fit(train.drop(['asin','overall'],axis=1))
# Let's find the k-neighbors of each point in object X. To do that we call the kneighbors() function on object X.
distances, indices = neighbor.kneighbors(train_array)

# %%
test.head()
# Out:
#             asin   overall  absolutely  accurate  actually  advertised  aid  \
# 7509  B00BB5YI0Q  3.035714           0         0         0           0    0
# 4324  B0057P3OUG  3.555556           0         0         0           0    0
# 7449  B00B4LEJBA  4.000000           0         0         0           0    0
# 2726  B004335OTM  3.950000           0         0         0           0    0
# 3853  B004V4LVW2  4.750000           0         0         0           0    0
#
#       allergy  alternative  amazing  ...    worked  working  workout  works  \
# 7509        0            0        0  ...         0        0        0      1
# 4324        0            0        0  ...         0        0        0      0
# 7449        0            0        0  ...         0        0        0      0
# 2726        0            0        0  ...         0        0        0      0
# 3853        0            0        0  ...         0        0        0      1
#
#       worth  wow  year  years  yes  yummy
# 7509      3    0     0      0    0      0
# 4324      0    0     0      0    0      0
# 7449      0    0     0      0    0      0
# 2726      0    0     0      0    0      0
# 3853      0    0     0      0    0      0
#
# [5 rows x 402 columns]

# %%
product_id.iloc[0]['asin']
# Out:
# 'B002DWA2H4'

# %%
test.asin.iloc[1]
# Out:
# 'B005K0MFNK'

# %%
#find most related products
for i in range(test.index.size):
    a = neighbor.kneighbors([test_array[i]])
    #print(a)
    print(a[0])
    print(a[1])
    related_product_list = a[1]
    
    first_related_product = [item[0] for item in related_product_list]
    first_related_product = str(first_related_product).strip('[]')
    first_related_product = int(first_related_product)
                             
    second_related_product = [item[1] for item in related_product_list]
    second_related_product = str(second_related_product).strip('[]')
    second_related_product = int(second_related_product)
    
    third_related_product = [item[2] for item in related_product_list]
    third_related_product = str(third_related_product).strip('[]')
    third_related_product = int(third_related_product)
    
    test_product=test.asin.iloc[i]
    s1=product_id['asin'][first_related_product]
    s2=product_id['asin'][second_related_product]
    s3=product_id['asin'][third_related_product]
    

    print ("Based on product reviews, for ",test_product," average rating is ",test.overall.iloc[i])
    print ("The first similar product is ", s1 ," average rating is ",product_id["overall"][first_related_product])
    print ("The second similar product is ",s2 ," average rating is ",product_id["overall"][second_related_product])
    print ("The third similar product is ",s3 ," average rating is ",product_id["overall"][third_related_product])
    print ("-----------------------------------------------------------")
# Out:
# [[ 3.46410162  3.60555128  3.60555128]]
# [[873 391 475]]
# Based on product reviews, for  B00DPMDWAA  average rating is  4.1
# The first similar product is  B002VWJZHY  average rating is  4.5
# The second similar product is  B002N616A2  average rating is  4.55555555556
# The third similar product is  B002PAR0EM  average rating is  2.42857142857
# -----------------------------------------------------------
# [[ 4.47213595  4.69041576  4.79583152]]
# [[1616  437  360]]
# Based on product reviews, for  B005K0MFNK  average rating is  4.08333333333
# The first similar product is  B003BJV7CM  average rating is  4.25
# The second similar product is  B002O7UI18  average rating is  4.7619047619
# The third similar product is  B002MTW2YO  average rating is  4.575
# -----------------------------------------------------------
# [[ 1.73205081  2.          2.        ]]
# [[5141  391 1759]]
# Based on product reviews, for  B003L66NWY  average rating is  4.83333333333
# The first similar product is  B0064EOF6G  average rating is  3.66666666667
# The second similar product is  B002N616A2  average rating is  4.55555555556
# The third similar product is  B003DX0LP0  average rating is  4.8
# -----------------------------------------------------------
# [[ 2.44948974  2.82842712  2.82842712]]
# [[ 919 5141 3174]]
# Based on product reviews, for  B00B4ZA244  average rating is  4.2
# The first similar product is  B002WN35LO  average rating is  4.625
# The second similar product is  B0064EOF6G  average rating is  3.66666666667
# The third similar product is  B004EW99SO  average rating is  4.07142857143
# -----------------------------------------------------------
# [[ 6.244998    6.78232998  6.92820323]]
# [[5288 2213 2028]]
# Based on product reviews, for  B00GYZ5XU2  average rating is  3.73333333333
# The first similar product is  B006GIYTX4  average rating is  4.85714285714
# The second similar product is  B003SSXVNE  average rating is  3.46666666667
# The third similar product is  B003LZNTLI  average rating is  4.6
# -----------------------------------------------------------
# [[ 2.82842712  3.31662479  3.31662479]]
# [[5918 1272   36]]
# Based on product reviews, for  B009VJ2MX4  average rating is  4.8
# The first similar product is  B007OZ2MGY  average rating is  4.09090909091
# The second similar product is  B0035880K6  average rating is  3.66666666667
# The third similar product is  B002ECZWPK  average rating is  4.11111111111
# -----------------------------------------------------------
# [[ 3.          3.16227766  3.16227766]]
# [[1659  475  961]]
# Based on product reviews, for  B003628ODO  average rating is  4.5
# The first similar product is  B003BWBRLA  average rating is  4.5
# The second similar product is  B002PAR0EM  average rating is  2.42857142857
# The third similar product is  B002XDRCRG  average rating is  4.6
# -----------------------------------------------------------
# [[ 2.64575131  2.64575131  2.82842712]]
# [[617 961 232]]
# Based on product reviews, for  B0064BUP0Y  average rating is  4.5
# The first similar product is  B002RTJ0JO  average rating is  5.0
# The second similar product is  B002XDRCRG  average rating is  4.6
# The third similar product is  B002JKP0UO  average rating is  3.7
# -----------------------------------------------------------
# [[ 6.32455532  6.4807407   6.4807407 ]]
# [[ 306 4973 2854]]
# Based on product reviews, for  B0069SQFSI  average rating is  4.58620689655
# The first similar product is  B002L5K40S  average rating is  4.0
# The second similar product is  B005V2UHIW  average rating is  4.53571428571
# The third similar product is  B0046DCJ6U  average rating is  4.36363636364
# -----------------------------------------------------------
# [[ 13.37908816  15.39480432  15.62049935]]
# [[ 724 2489 2256]]
# Based on product reviews, for  B007VAXSYC  average rating is  4.0625
# The first similar product is  B002TG3TPG  average rating is  3.6
# The second similar product is  B003YIDYNU  average rating is  4.16666666667
# The third similar product is  B003U3CJWQ  average rating is  3.35714285714
# -----------------------------------------------------------
# [[ 12.489996    16.43167673  16.55294536]]
# [[1862 3915 4434]]
# Based on product reviews, for  B004C7MTLA  average rating is  4.73493975904
# The first similar product is  B003H3G470  average rating is  2.85714285714
# The second similar product is  B004W6X6B8  average rating is  4.375
# The third similar product is  B005C4WQS8  average rating is  4.3
# -----------------------------------------------------------
# [[ 3.          3.16227766  3.16227766]]
# [[4853  174  310]]
# Based on product reviews, for  B00BCY06D4  average rating is  4.9
# The first similar product is  B005NZ66KU  average rating is  4.43925233645
# The second similar product is  B002I9LVFE  average rating is  3.0
# The third similar product is  B002LAS16W  average rating is  4.14285714286
# -----------------------------------------------------------
# [[ 4.12310563  4.12310563  4.24264069]]
# [[4152  325 2475]]
# Based on product reviews, for  B004DHK1KK  average rating is  4.41666666667
# The first similar product is  B0052NAS6G  average rating is  5.0
# The second similar product is  B002LMLN9W  average rating is  4.6
# The third similar product is  B003Y8Y9QQ  average rating is  3.4
# -----------------------------------------------------------
# [[ 3.16227766  3.31662479  3.31662479]]
# [[1889  856  124]]
# Based on product reviews, for  B003KJ31Z4  average rating is  4.6
# The first similar product is  B003I7BGH8  average rating is  4.95238095238
# The second similar product is  B002VTWW3Q  average rating is  4.26315789474
# The third similar product is  B002GU796A  average rating is  3.88235294118
# -----------------------------------------------------------
# [[ 4.35889894  4.47213595  4.47213595]]
# [[3444  889 1653]]
# Based on product reviews, for  B00G2NOZS2  average rating is  4.77777777778
# The first similar product is  B004LL2TWG  average rating is  3.94736842105
# The second similar product is  B002VWKOHY  average rating is  4.2
# The third similar product is  B003BVINRC  average rating is  4.63106796117
# -----------------------------------------------------------
# [[ 3.16227766  3.31662479  3.31662479]]
# [[3762 5558 4896]]
# Based on product reviews, for  B0054TNKXQ  average rating is  4.25
# The first similar product is  B004T8WDMW  average rating is  4.0
# The second similar product is  B0073RLP3Y  average rating is  4.77777777778
# The third similar product is  B005PHUAD0  average rating is  4.8
# -----------------------------------------------------------
# [[ 4.          4.12310563  4.24264069]]
# [[6177 1119 3981]]
# Based on product reviews, for  B008VT6N3U  average rating is  4.08333333333
# The first similar product is  B00817GTV8  average rating is  4.2
# The second similar product is  B0030HKZ50  average rating is  4.4328358209
# The third similar product is  B004XVNDL0  average rating is  4.63636363636
# -----------------------------------------------------------
# [[ 17.74823935  18.30300522  18.94729532]]
# [[2509  203  139]]
# Based on product reviews, for  B00DN6V5G6  average rating is  3.68055555556
# The first similar product is  B003YSVBEO  average rating is  4.27272727273
# The second similar product is  B002J9HBX4  average rating is  4.60280373832
# The third similar product is  B002HMCINQ  average rating is  4.16666666667
# -----------------------------------------------------------
# [[ 13.11487705  13.85640646  14.49137675]]
# [[5392 5377 2036]]
# Based on product reviews, for  B00537128O  average rating is  4.53125
# The first similar product is  B006OQ4316  average rating is  4.33962264151
# The second similar product is  B006NZH0TU  average rating is  4.65
# The third similar product is  B003M5JR9K  average rating is  4.42857142857
# -----------------------------------------------------------
# [[ 9.43398113  9.48683298  9.48683298]]
# [[1939 4113 4393]]
# Based on product reviews, for  B002W6Z0YG  average rating is  3.88888888889
# The first similar product is  B003JO1XLY  average rating is  4.6
# The second similar product is  B0051GAKI0  average rating is  3.39325842697
# The third similar product is  B005AYC01I  average rating is  4.5
# -----------------------------------------------------------
# [[ 4.47213595  4.58257569  4.58257569]]
# [[ 937 3532  563]]
# Based on product reviews, for  B00E9IQUI0  average rating is  3.92307692308
# The first similar product is  B002WTCLG8  average rating is  4.45454545455
# The second similar product is  B004O25RJ4  average rating is  4.2
# The third similar product is  B002RD182M  average rating is  3.4
# -----------------------------------------------------------
# [[ 2.          2.          2.23606798]]
# [[ 391 5339 1322]]
# Based on product reviews, for  B009VLBPI0  average rating is  4.66666666667
# The first similar product is  B002N616A2  average rating is  4.55555555556
# The second similar product is  B006KXSOA4  average rating is  4.63636363636
# The third similar product is  B00367ROI0  average rating is  3.0
# -----------------------------------------------------------
# [[ 12.4498996   13.41640786  13.89244399]]
# [[5932 2072 4820]]
# Based on product reviews, for  B0079M8T2I  average rating is  4.66666666667
# The first similar product is  B007P8DU6Q  average rating is  4.2
# The second similar product is  B003N4AVKE  average rating is  4.32352941176
# The third similar product is  B005MYYZQ4  average rating is  3.33333333333
# -----------------------------------------------------------
# [[ 27.71281292  28.16025568  28.19574436]]
# [[5050  773 5187]]
# Based on product reviews, for  B007VAGXDK  average rating is  4.00961538462
# The first similar product is  B005YU8S0A  average rating is  4.83333333333
# The second similar product is  B002UPT1B2  average rating is  4.8
# The third similar product is  B006764NZO  average rating is  4.85714285714
# -----------------------------------------------------------
# [[ 12.08304597  12.16552506  12.28820573]]
# [[2463 1669 2666]]
# Based on product reviews, for  B0049MIF1G  average rating is  4.55813953488
# The first similar product is  B003XU8AMY  average rating is  4.22222222222
# The second similar product is  B003C54M9A  average rating is  4.5
# The third similar product is  B00424KNWA  average rating is  4.66666666667
# -----------------------------------------------------------
# [[ 14.07124728  15.19868415  15.26433752]]
# [[3600 5706 4615]]
# Based on product reviews, for  B00I8H6FUG  average rating is  3.85416666667
# The first similar product is  B004PHD2YU  average rating is  5.0
# The second similar product is  B007AHK1EG  average rating is  3.0
# The third similar product is  B005GLJSHO  average rating is  4.32352941176
# -----------------------------------------------------------
# [[ 52.82991577  54.61684722  57.        ]]
# [[6202 2016 2898]]
# Based on product reviews, for  B0091DS0U4  average rating is  4.36868686869
# The first similar product is  B0082FKTI8  average rating is  2.77777777778
# The second similar product is  B003LSRW3G  average rating is  4.33333333333
# The third similar product is  B00478PI2G  average rating is  5.0
# -----------------------------------------------------------
# [[ 2.82842712  3.16227766  3.31662479]]
# [[5956 1274   11]]
# Based on product reviews, for  B004YG7LEE  average rating is  4.875
# The first similar product is  B007RA6A3M  average rating is  3.66666666667
# The second similar product is  B00359FB98  average rating is  4.14285714286
# The third similar product is  B002DYJ0K2  average rating is  4.36734693878
# -----------------------------------------------------------
# [[ 11.5758369   12.04159458  12.36931688]]
# [[2285 4618  214]]
# Based on product reviews, for  B00L1H4I0Y  average rating is  4.81081081081
# The first similar product is  B003UEH7DQ  average rating is  4.0
# The second similar product is  B005GLWRTU  average rating is  3.375
# The third similar product is  B002JINMOM  average rating is  3.94117647059
# -----------------------------------------------------------
# [[ 9.          9.53939201  9.64365076]]
# [[1676 2591 6074]]
# Based on product reviews, for  B0042RPE1C  average rating is  4.84375
# The first similar product is  B003CFB2A2  average rating is  3.85714285714
# The second similar product is  B0040USG8O  average rating is  4.4
# The third similar product is  B007WIAJ7M  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 10.86278049  10.90871211  11.09053651]]
# [[ 286 6182 5444]]
# Based on product reviews, for  B00EI4NGE6  average rating is  3.75
# The first similar product is  B002KK28EE  average rating is  4.33333333333
# The second similar product is  B0081KMBE4  average rating is  4.45454545455
# The third similar product is  B006T77ANS  average rating is  4.42857142857
# -----------------------------------------------------------
# [[ 4.47213595  4.47213595  4.47213595]]
# [[3491   30 2703]]
# Based on product reviews, for  B004I6AFD4  average rating is  4.0
# The first similar product is  B004N731ZM  average rating is  4.28571428571
# The second similar product is  B002E9HZXU  average rating is  3.72727272727
# The third similar product is  B0042RPDYU  average rating is  4.14285714286
# -----------------------------------------------------------
# [[ 3.31662479  3.46410162  3.46410162]]
# [[ 343 2307 2194]]
# Based on product reviews, for  B0043CE8VS  average rating is  4.16666666667
# The first similar product is  B002M6MV8Y  average rating is  5.0
# The second similar product is  B003ULGGZY  average rating is  4.65957446809
# The third similar product is  B003S0KDL0  average rating is  4.85714285714
# -----------------------------------------------------------
# [[ 22.95648057  27.44084547  33.        ]]
# [[ 677 4046 1741]]
# Based on product reviews, for  B004Q7CK56  average rating is  4.41176470588
# The first similar product is  B002SG6HPQ  average rating is  3.8
# The second similar product is  B004ZCT1QI  average rating is  4.83333333333
# The third similar product is  B003DLZ0OE  average rating is  4.38888888889
# -----------------------------------------------------------
# [[ 15.93737745  15.93737745  16.46207763]]
# [[1131 1444 5084]]
# Based on product reviews, for  B003GWH60G  average rating is  4.35
# The first similar product is  B0030L05GA  average rating is  5.0
# The second similar product is  B0038BWLB4  average rating is  3.09090909091
# The third similar product is  B0061ITIUI  average rating is  4.6875
# -----------------------------------------------------------
# [[ 4.24264069  4.35889894  4.58257569]]
# [[3108 1894 5358]]
# Based on product reviews, for  B0057LXKUO  average rating is  4.75
# The first similar product is  B004DGL3BC  average rating is  4.14285714286
# The second similar product is  B003IABAS0  average rating is  4.85714285714
# The third similar product is  B006M3YNKC  average rating is  3.52941176471
# -----------------------------------------------------------
# [[ 8.60232527  8.60232527  9.38083152]]
# [[6065  198 4892]]
# Based on product reviews, for  B002RTXEW8  average rating is  4.33333333333
# The first similar product is  B007W5292I  average rating is  3.83333333333
# The second similar product is  B002J0PD5Q  average rating is  4.0625
# The third similar product is  B005P7PDGE  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 2.44948974  2.44948974  2.64575131]]
# [[2952 3712  830]]
# Based on product reviews, for  B0037KM8QY  average rating is  3.66666666667
# The first similar product is  B00498MSJ0  average rating is  4.31818181818
# The second similar product is  B004RR1FF6  average rating is  4.83333333333
# The third similar product is  B002VLZ86M  average rating is  4.5
# -----------------------------------------------------------
# [[ 2.23606798  2.23606798  2.64575131]]
# [[ 791 2574  449]]
# Based on product reviews, for  B003NQWXJ4  average rating is  5.0
# The first similar product is  B002UVU7HS  average rating is  4.375
# The second similar product is  B00404RI70  average rating is  3.94117647059
# The third similar product is  B002ONHBBW  average rating is  3.875
# -----------------------------------------------------------
# [[ 3.87298335  4.          4.        ]]
# [[3002   60  339]]
# Based on product reviews, for  B0041MU0A8  average rating is  4.88888888889
# The first similar product is  B004AI8QPO  average rating is  3.5
# The second similar product is  B002FCFEZ2  average rating is  4.4
# The third similar product is  B002LZCLH2  average rating is  4.5
# -----------------------------------------------------------
# [[ 8.1240384   8.1240384   8.18535277]]
# [[1256 2196  559]]
# Based on product reviews, for  B00JFHYY42  average rating is  4.92592592593
# The first similar product is  B0034CHMRU  average rating is  4.54545454545
# The second similar product is  B003S4XC2I  average rating is  3.9
# The third similar product is  B002RBF1PO  average rating is  4.75446428571
# -----------------------------------------------------------
# [[ 2.64575131  2.82842712  2.82842712]]
# [[1655  391  358]]
# Based on product reviews, for  B003M5MP9Y  average rating is  5.0
# The first similar product is  B003BVINSG  average rating is  4.75
# The second similar product is  B002N616A2  average rating is  4.55555555556
# The third similar product is  B002MPPYWK  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 6.244998    6.40312424  6.70820393]]
# [[4449 5311 1063]]
# Based on product reviews, for  B00G2FZH4G  average rating is  4.76470588235
# The first similar product is  B005CDC7LA  average rating is  4.0
# The second similar product is  B006HW5J9C  average rating is  4.42857142857
# The third similar product is  B002ZFYN1U  average rating is  4.2
# -----------------------------------------------------------
# [[ 2.82842712  2.82842712  3.        ]]
# [[ 787  820 1012]]
# Based on product reviews, for  B00638EXRY  average rating is  3.6
# The first similar product is  B002UUTCZ2  average rating is  4.14754098361
# The second similar product is  B002VKB4O8  average rating is  3.55555555556
# The third similar product is  B002YB034G  average rating is  4.66666666667
# -----------------------------------------------------------
# [[ 2.64575131  2.64575131  2.64575131]]
# [[5700 1114 3313]]
# Based on product reviews, for  B004XI3O3U  average rating is  3.8
# The first similar product is  B007A4WZK2  average rating is  4.14285714286
# The second similar product is  B0030GXSVE  average rating is  4.4
# The third similar product is  B004I1CXE8  average rating is  4.25
# -----------------------------------------------------------
# [[ 1.73205081  2.23606798  2.23606798]]
# [[3104 3903 1423]]
# Based on product reviews, for  B00B2C78ZA  average rating is  3.4
# The first similar product is  B004DEXE48  average rating is  4.16666666667
# The second similar product is  B004W2DW1G  average rating is  3.66666666667
# The third similar product is  B0037UWO90  average rating is  4.5
# -----------------------------------------------------------
# [[ 4.12310563  4.12310563  4.35889894]]
# [[2209 2231 3834]]
# Based on product reviews, for  B004T8WF84  average rating is  4.125
# The first similar product is  B003SP4QAE  average rating is  4.1320754717
# The second similar product is  B003TN6JE6  average rating is  3.66666666667
# The third similar product is  B004UMOWBM  average rating is  3.27272727273
# -----------------------------------------------------------
# [[ 2.64575131  2.64575131  2.64575131]]
# [[5130  783  655]]
# Based on product reviews, for  B00537HNZ0  average rating is  4.8
# The first similar product is  B0063G8ZW0  average rating is  3.6
# The second similar product is  B002UUSY3S  average rating is  4.0303030303
# The third similar product is  B002S52WWE  average rating is  4.54166666667
# -----------------------------------------------------------
# [[ 7.          7.61577311  7.81024968]]
# [[2591 1896 6074]]
# Based on product reviews, for  B002RTNUEA  average rating is  4.65625
# The first similar product is  B0040USG8O  average rating is  4.4
# The second similar product is  B003IEJTYI  average rating is  4.85714285714
# The third similar product is  B007WIAJ7M  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 6.63324958  6.63324958  6.63324958]]
# [[5841 5060 4031]]
# Based on product reviews, for  B0052458M4  average rating is  4.23529411765
# The first similar product is  B007JYN2AU  average rating is  3.94117647059
# The second similar product is  B005YU8X6O  average rating is  4.375
# The third similar product is  B004YTL340  average rating is  4.71428571429
# -----------------------------------------------------------
# [[ 3.31662479  3.60555128  3.60555128]]
# [[ 116 5740 2536]]
# Based on product reviews, for  B002MQ962I  average rating is  3.8
# The first similar product is  B002GU5YCG  average rating is  4.27419354839
# The second similar product is  B007CV6FTA  average rating is  3.19047619048
# The third similar product is  B003Z67ENC  average rating is  3.53846153846
# -----------------------------------------------------------
# [[ 4.58257569  4.69041576  4.79583152]]
# [[5642 2530 1895]]
# Based on product reviews, for  B008RD60KG  average rating is  3.52380952381
# The first similar product is  B00777ZIHO  average rating is  4.66666666667
# The second similar product is  B003YZOGO4  average rating is  4.6835443038
# The third similar product is  B003IE8SCM  average rating is  4.57142857143
# -----------------------------------------------------------
# [[ 3.16227766  3.31662479  3.31662479]]
# [[3023 5319 3093]]
# Based on product reviews, for  B00EBGRFDE  average rating is  5.0
# The first similar product is  B004ASW9MA  average rating is  4.64347826087
# The second similar product is  B006JAPSOI  average rating is  4.90909090909
# The third similar product is  B004D0E80G  average rating is  4.4
# -----------------------------------------------------------
# [[ 2.44948974  2.44948974  2.44948974]]
# [[5339 2631 4266]]
# Based on product reviews, for  B00H87U01W  average rating is  5.0
# The first similar product is  B006KXSOA4  average rating is  4.63636363636
# The second similar product is  B0041MR9R0  average rating is  4.71428571429
# The third similar product is  B00563E6ZG  average rating is  4.26666666667
# -----------------------------------------------------------
# [[ 6.08276253  6.164414    6.164414  ]]
# [[ 490 5323 2018]]
# Based on product reviews, for  B0055QA7U2  average rating is  4.86666666667
# The first similar product is  B002PKTCRU  average rating is  4.875
# The second similar product is  B006JR1N72  average rating is  4.19672131148
# The third similar product is  B003LUDNIM  average rating is  4.625
# -----------------------------------------------------------
# [[ 11.78982612  12.          12.        ]]
# [[5858 5926 2478]]
# Based on product reviews, for  B004BD71JK  average rating is  3.91780821918
# The first similar product is  B007L0DL8K  average rating is  4.66666666667
# The second similar product is  B007P5VZ02  average rating is  4.33333333333
# The third similar product is  B003YCGWBC  average rating is  4.06451612903
# -----------------------------------------------------------
# [[ 1.41421356  1.41421356  1.41421356]]
# [[910 358 391]]
# Based on product reviews, for  B009D1WU5A  average rating is  5.0
# The first similar product is  B002WJHC58  average rating is  3.14285714286
# The second similar product is  B002MPPYWK  average rating is  4.33333333333
# The third similar product is  B002N616A2  average rating is  4.55555555556
# -----------------------------------------------------------
# [[ 5.19615242  5.29150262  5.47722558]]
# [[3370 4422 2473]]
# Based on product reviews, for  B0086VI9SU  average rating is  4.71428571429
# The first similar product is  B004JLK4JS  average rating is  4.0
# The second similar product is  B005BPCAKC  average rating is  2.71428571429
# The third similar product is  B003Y6B4XE  average rating is  4.1
# -----------------------------------------------------------
# [[ 3.46410162  3.46410162  3.60555128]]
# [[1363 2712 5918]]
# Based on product reviews, for  B00BWFCOYC  average rating is  4.375
# The first similar product is  B0036THMJY  average rating is  4.66666666667
# The second similar product is  B0042YU6RC  average rating is  4.875
# The third similar product is  B007OZ2MGY  average rating is  4.09090909091
# -----------------------------------------------------------
# [[ 3.          3.31662479  3.60555128]]
# [[4546 3595 2046]]
# Based on product reviews, for  B002RWX8VM  average rating is  3.35714285714
# The first similar product is  B005F1ATJQ  average rating is  4.68571428571
# The second similar product is  B004PC49HE  average rating is  3.55
# The third similar product is  B003MP16A8  average rating is  3.65
# -----------------------------------------------------------
# [[ 3.31662479  3.46410162  3.46410162]]
# [[ 674 3604   36]]
# Based on product reviews, for  B0097OY70Y  average rating is  4.66666666667
# The first similar product is  B002SG6HOC  average rating is  4.25
# The second similar product is  B004PPRLW6  average rating is  4.19047619048
# The third similar product is  B002ECZWPK  average rating is  4.11111111111
# -----------------------------------------------------------
# [[ 2.          2.44948974  2.44948974]]
# [[3625  391  458]]
# Based on product reviews, for  B00ETBOAAC  average rating is  5.0
# The first similar product is  B004QC7L50  average rating is  4.67532467532
# The second similar product is  B002N616A2  average rating is  4.55555555556
# The third similar product is  B002OTXTA8  average rating is  5.0
# -----------------------------------------------------------
# [[ 5.65685425  5.83095189  5.91607978]]
# [[ 202  360 1807]]
# Based on product reviews, for  B002DYJ0AW  average rating is  4.33333333333
# The first similar product is  B002J5K5R2  average rating is  5.0
# The second similar product is  B002MTW2YO  average rating is  4.575
# The third similar product is  B003FBPFJW  average rating is  3.28571428571
# -----------------------------------------------------------
# [[ 3.87298335  4.          4.        ]]
# [[2660 2169 2081]]
# Based on product reviews, for  B002WWF4IM  average rating is  3.66666666667
# The first similar product is  B004242558  average rating is  4.70833333333
# The second similar product is  B003QMUX2O  average rating is  3.89473684211
# The third similar product is  B003NLL5AC  average rating is  3.4
# -----------------------------------------------------------
# [[ 13.19090596  14.38749457  14.49137675]]
# [[ 934  316 1401]]
# Based on product reviews, for  B00GM029TC  average rating is  3.1875
# The first similar product is  B002WTCK4Q  average rating is  3.41463414634
# The second similar product is  B002LGY10G  average rating is  4.31578947368
# The third similar product is  B0037KM82S  average rating is  4.83333333333
# -----------------------------------------------------------
# [[ 2.64575131  2.64575131  2.64575131]]
# [[3710 1278 2499]]
# Based on product reviews, for  B0057D83RM  average rating is  4.11111111111
# The first similar product is  B004RQ4ACW  average rating is  4.0
# The second similar product is  B00359FBHK  average rating is  4.28571428571
# The third similar product is  B003YKCSDA  average rating is  4.4
# -----------------------------------------------------------
# [[ 15.06651917  16.21727474  16.40121947]]
# [[3635 1325 5115]]
# Based on product reviews, for  B003V3476G  average rating is  4.43103448276
# The first similar product is  B004QHCGF0  average rating is  4.0
# The second similar product is  B0036B7ZYE  average rating is  4.34920634921
# The third similar product is  B0062N5AZO  average rating is  4.4375
# -----------------------------------------------------------
# [[ 5.74456265  5.74456265  5.83095189]]
# [[1558 1947 3460]]
# Based on product reviews, for  B002RXECHU  average rating is  4.65
# The first similar product is  B003AT0QAW  average rating is  4.0
# The second similar product is  B003JVE7FQ  average rating is  5.0
# The third similar product is  B004LZEPHO  average rating is  3.94285714286
# -----------------------------------------------------------
# [[ 5.47722558  6.          6.40312424]]
# [[1071 3054 2196]]
# Based on product reviews, for  B004OJM9XE  average rating is  4.41666666667
# The first similar product is  B002ZG8HXE  average rating is  4.11111111111
# The second similar product is  B004BKLHFC  average rating is  4.28571428571
# The third similar product is  B003S4XC2I  average rating is  3.9
# -----------------------------------------------------------
# [[ 2.23606798  2.44948974  2.64575131]]
# [[6330  923  232]]
# Based on product reviews, for  B004RPOURI  average rating is  5.0
# The first similar product is  B0087OOL0Q  average rating is  4.55555555556
# The second similar product is  B002WQ7XS2  average rating is  4.2
# The third similar product is  B002JKP0UO  average rating is  3.7
# -----------------------------------------------------------
# [[ 2.44948974  2.44948974  2.44948974]]
# [[2995 1319 2882]]
# Based on product reviews, for  B004L5L2VQ  average rating is  3.6
# The first similar product is  B004AFXG34  average rating is  3.33333333333
# The second similar product is  B00363VK3O  average rating is  3.72727272727
# The third similar product is  B00471400O  average rating is  4.92857142857
# -----------------------------------------------------------
# [[ 12.12435565  13.41640786  13.74772708]]
# [[6295 2604 1386]]
# Based on product reviews, for  B00ECBTEM8  average rating is  4.07142857143
# The first similar product is  B00863XN4I  average rating is  4.6
# The second similar product is  B004153NK4  average rating is  4.14285714286
# The third similar product is  B00373NN2E  average rating is  4.44444444444
# -----------------------------------------------------------
# [[ 12.84523258  13.6381817   13.67479433]]
# [[5752 3139 1393]]
# Based on product reviews, for  B0091E51IC  average rating is  2.9375
# The first similar product is  B007E4ZZPU  average rating is  4.425
# The second similar product is  B004DTXHBS  average rating is  4.9
# The third similar product is  B0037B1JGI  average rating is  5.0
# -----------------------------------------------------------
# [[ 3.87298335  3.87298335  4.        ]]
# [[1404 6083 1089]]
# Based on product reviews, for  B004E5GV82  average rating is  4.8
# The first similar product is  B0037KMI0A  average rating is  3.97058823529
# The second similar product is  B007WTI6FI  average rating is  3.75
# The third similar product is  B002ZVM20I  average rating is  4.55555555556
# -----------------------------------------------------------
# [[ 14.10673598  14.24780685  14.62873884]]
# [[1699 1975 6235]]
# Based on product reviews, for  B008KEJ1US  average rating is  4.0
# The first similar product is  B003CP15JK  average rating is  4.91666666667
# The second similar product is  B003KVNZX0  average rating is  3.28205128205
# The third similar product is  B00843U7MQ  average rating is  3.28571428571
# -----------------------------------------------------------
# [[ 3.60555128  3.60555128  3.60555128]]
# [[6373 1596 3818]]
# Based on product reviews, for  B0031JK91W  average rating is  2.57142857143
# The first similar product is  B008AJKJEK  average rating is  3.625
# The second similar product is  B003BAJOEE  average rating is  3.71428571429
# The third similar product is  B004UDWU6K  average rating is  4.57142857143
# -----------------------------------------------------------
# [[ 6.32455532  6.32455532  6.40312424]]
# [[ 192 5857  429]]
# Based on product reviews, for  B002JINUJE  average rating is  4.41176470588
# The first similar product is  B002IT3D78  average rating is  4.1
# The second similar product is  B007L0DDOC  average rating is  4.5
# The third similar product is  B002NW3G0Y  average rating is  4.6
# -----------------------------------------------------------
# [[ 3.16227766  3.31662479  3.31662479]]
# [[2751 5368 3465]]
# Based on product reviews, for  B005OOOGZM  average rating is  4.75
# The first similar product is  B0043P0I1O  average rating is  4.83333333333
# The second similar product is  B006N8F8NM  average rating is  4.4
# The third similar product is  B004M37A0O  average rating is  4.48387096774
# -----------------------------------------------------------
# [[ 3.87298335  3.87298335  4.        ]]
# [[3002 5475 3796]]
# Based on product reviews, for  B0069SQD6W  average rating is  4.55555555556
# The first similar product is  B004AI8QPO  average rating is  3.5
# The second similar product is  B006VYSZBA  average rating is  4.35294117647
# The third similar product is  B004U1PHJY  average rating is  4.14285714286
# -----------------------------------------------------------
# [[ 3.          3.16227766  3.16227766]]
# [[655 362 505]]
# Based on product reviews, for  B003VZW6O4  average rating is  2.875
# The first similar product is  B002S52WWE  average rating is  4.54166666667
# The second similar product is  B002MUAP2E  average rating is  3.8
# The third similar product is  B002Q1CGAS  average rating is  4.47619047619
# -----------------------------------------------------------
# [[ 4.79583152  4.79583152  4.89897949]]
# [[2926 5928 4124]]
# Based on product reviews, for  B005VTQ1NK  average rating is  4.9
# The first similar product is  B0048BGUN8  average rating is  4.64285714286
# The second similar product is  B007P63SCE  average rating is  4.8
# The third similar product is  B0051VVVZG  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 3.87298335  4.          4.        ]]
# [[ 174 3833 2802]]
# Based on product reviews, for  B0057D7YGS  average rating is  4.41666666667
# The first similar product is  B002I9LVFE  average rating is  3.0
# The second similar product is  B004UKSLFC  average rating is  3.671875
# The third similar product is  B0044ZY0VW  average rating is  3.0
# -----------------------------------------------------------
# [[ 4.12310563  4.24264069  4.35889894]]
# [[3173 4327  565]]
# Based on product reviews, for  B004O672F2  average rating is  3.11111111111
# The first similar product is  B004EVJ2M8  average rating is  4.72727272727
# The second similar product is  B0057RHH98  average rating is  3.6
# The third similar product is  B002RH6ZQC  average rating is  4.4
# -----------------------------------------------------------
# [[ 2.          2.23606798  2.23606798]]
# [[4504 5718 4853]]
# Based on product reviews, for  B00HIM5D6O  average rating is  5.0
# The first similar product is  B005DM0S5C  average rating is  4.0
# The second similar product is  B007BFT1IE  average rating is  3.2
# The third similar product is  B005NZ66KU  average rating is  4.43925233645
# -----------------------------------------------------------
# [[ 3.          3.          3.16227766]]
# [[3712 4058  508]]
# Based on product reviews, for  B004GN32RA  average rating is  3.2
# The first similar product is  B004RR1FF6  average rating is  4.83333333333
# The second similar product is  B004ZMLWZG  average rating is  4.19512195122
# The third similar product is  B002Q4V46C  average rating is  5.0
# -----------------------------------------------------------
# [[ 3.60555128  3.74165739  3.87298335]]
# [[1031  538 1836]]
# Based on product reviews, for  B007IL88FS  average rating is  4.0
# The first similar product is  B002YIO56Q  average rating is  4.0
# The second similar product is  B002QVY9EO  average rating is  4.83333333333
# The third similar product is  B003G4BPG0  average rating is  4.13333333333
# -----------------------------------------------------------
# [[  9.43398113   9.64365076  10.        ]]
# [[ 974 3086 5004]]
# Based on product reviews, for  B0030HG054  average rating is  4.61764705882
# The first similar product is  B002XN20D2  average rating is  3.75
# The second similar product is  B004CQ5NUK  average rating is  4.55172413793
# The third similar product is  B005VSXUQM  average rating is  3.88235294118
# -----------------------------------------------------------
# [[ 3.31662479  3.46410162  3.46410162]]
# [[2060  937  873]]
# Based on product reviews, for  B004OR1U1S  average rating is  3.75
# The first similar product is  B003MWJKCW  average rating is  3.75
# The second similar product is  B002WTCLG8  average rating is  4.45454545455
# The third similar product is  B002VWJZHY  average rating is  4.5
# -----------------------------------------------------------
# [[ 5.56776436  5.56776436  5.56776436]]
# [[5528 1073 2445]]
# Based on product reviews, for  B0087S7WXU  average rating is  3.14285714286
# The first similar product is  B0071O8B3G  average rating is  3.26666666667
# The second similar product is  B002ZHXVWU  average rating is  4.11428571429
# The third similar product is  B003XDZ6NM  average rating is  1.42857142857
# -----------------------------------------------------------
# [[ 3.31662479  3.31662479  3.31662479]]
# [[5114 3862  310]]
# Based on product reviews, for  B007ZDGIW4  average rating is  3.4
# The first similar product is  B0062K6QG4  average rating is  4.36363636364
# The second similar product is  B004V9ICTM  average rating is  4.4
# The third similar product is  B002LAS16W  average rating is  4.14285714286
# -----------------------------------------------------------
# [[ 3.          3.16227766  3.16227766]]
# [[ 116 5583 2795]]
# Based on product reviews, for  B0054N8M26  average rating is  4.75
# The first similar product is  B002GU5YCG  average rating is  4.27419354839
# The second similar product is  B0074OVAGS  average rating is  4.90909090909
# The third similar product is  B0044Q8VG6  average rating is  4.4
# -----------------------------------------------------------
# [[ 4.24264069  4.24264069  4.24264069]]
# [[1304  197  510]]
# Based on product reviews, for  B003IRNUQI  average rating is  4.61538461538
# The first similar product is  B0035OJJ8C  average rating is  4.2
# The second similar product is  B002J0KC02  average rating is  4.35714285714
# The third similar product is  B002Q8JQYU  average rating is  4.42857142857
# -----------------------------------------------------------
# [[ 5.56776436  5.56776436  5.83095189]]
# [[3925 2932  429]]
# Based on product reviews, for  B003G4BP5G  average rating is  4.5
# The first similar product is  B004WIA6TQ  average rating is  4.0
# The second similar product is  B0048IGBD0  average rating is  3.7619047619
# The third similar product is  B002NW3G0Y  average rating is  4.6
# -----------------------------------------------------------
# [[ 3.31662479  3.31662479  3.46410162]]
# [[5399 4110 2220]]
# Based on product reviews, for  B005KQB22E  average rating is  4.41666666667
# The first similar product is  B006P0ZENM  average rating is  5.0
# The second similar product is  B00519PTHO  average rating is  4.85714285714
# The third similar product is  B003TBYW74  average rating is  3.0
# -----------------------------------------------------------
# [[ 3.16227766  3.31662479  3.31662479]]
# [[1889  401  856]]
# Based on product reviews, for  B00FDE09LI  average rating is  4.33333333333
# The first similar product is  B003I7BGH8  average rating is  4.95238095238
# The second similar product is  B002NGOORY  average rating is  4.66666666667
# The third similar product is  B002VTWW3Q  average rating is  4.26315789474
# -----------------------------------------------------------
# [[ 1.41421356  1.73205081  1.73205081]]
# [[5848 1423 3104]]
# Based on product reviews, for  B002LVV3XY  average rating is  4.16666666667
# The first similar product is  B007KDE9DY  average rating is  3.8
# The second similar product is  B0037UWO90  average rating is  4.5
# The third similar product is  B004DEXE48  average rating is  4.16666666667
# -----------------------------------------------------------
# [[ 4.35889894  4.35889894  4.47213595]]
# [[2660 5070 4323]]
# Based on product reviews, for  B002SRATBI  average rating is  3.8125
# The first similar product is  B004242558  average rating is  4.70833333333
# The second similar product is  B005ZDIBAS  average rating is  4.85714285714
# The third similar product is  B0057ON4PM  average rating is  3.61538461538
# -----------------------------------------------------------
# [[ 5.19615242  5.19615242  5.38516481]]
# [[3940 5609 4253]]
# Based on product reviews, for  B002VTWW3Q  average rating is  4.26315789474
# The first similar product is  B004WPJBDG  average rating is  4.18965517241
# The second similar product is  B00764F2M4  average rating is  4.6
# The third similar product is  B0055OUGUU  average rating is  3.72906403941
# -----------------------------------------------------------
# [[ 1.73205081  2.          2.        ]]
# [[6014  820 2751]]
# Based on product reviews, for  B00FZWQJZI  average rating is  3.6
# The first similar product is  B007TYY3NU  average rating is  4.16666666667
# The second similar product is  B002VKB4O8  average rating is  3.55555555556
# The third similar product is  B0043P0I1O  average rating is  4.83333333333
# -----------------------------------------------------------
# [[ 3.60555128  3.74165739  3.74165739]]
# [[2626 3710 2962]]
# Based on product reviews, for  B00KI1SZ9Y  average rating is  5.0
# The first similar product is  B0041IK7R8  average rating is  2.66666666667
# The second similar product is  B004RQ4ACW  average rating is  4.0
# The third similar product is  B0049MEI5S  average rating is  4.43902439024
# -----------------------------------------------------------
# [[ 3.          3.16227766  3.16227766]]
# [[ 894 2176 1655]]
# Based on product reviews, for  B00431PRHI  average rating is  4.42857142857
# The first similar product is  B002W7NMAY  average rating is  4.88888888889
# The second similar product is  B003QY8BJE  average rating is  4.80769230769
# The third similar product is  B003BVINSG  average rating is  4.75
# -----------------------------------------------------------
# [[ 5.65685425  5.74456265  5.91607978]]
# [[2841 6134 2089]]
# Based on product reviews, for  B005GD1ERE  average rating is  5.0
# The first similar product is  B0045XGE9E  average rating is  3.96610169492
# The second similar product is  B007ZDGIW4  average rating is  3.4
# The third similar product is  B003NS39X6  average rating is  3.87878787879
# -----------------------------------------------------------
# [[ 3.16227766  3.46410162  3.46410162]]
# [[4039   14  325]]
# Based on product reviews, for  B00A9T30DQ  average rating is  4.6
# The first similar product is  B004Z5GYVU  average rating is  3.9
# The second similar product is  B002DYJ0P2  average rating is  4.33333333333
# The third similar product is  B002LMLN9W  average rating is  4.6
# -----------------------------------------------------------
# [[ 3.31662479  3.87298335  3.87298335]]
# [[2187  606  275]]
# Based on product reviews, for  B0049MIEI0  average rating is  4.0
# The first similar product is  B003RGO3ES  average rating is  4.2
# The second similar product is  B002RSXP28  average rating is  4.72972972973
# The third similar product is  B002KHNL3E  average rating is  4.09090909091
# -----------------------------------------------------------
# [[ 4.12310563  4.12310563  4.24264069]]
# [[5918  674   36]]
# Based on product reviews, for  B007JIRYZU  average rating is  4.81818181818
# The first similar product is  B007OZ2MGY  average rating is  4.09090909091
# The second similar product is  B002SG6HOC  average rating is  4.25
# The third similar product is  B002ECZWPK  average rating is  4.11111111111
# -----------------------------------------------------------
# [[ 2.64575131  3.16227766  3.16227766]]
# [[1103 4315 2882]]
# Based on product reviews, for  B009041FYM  average rating is  4.71428571429
# The first similar product is  B00309S4C4  average rating is  4.25
# The second similar product is  B0057D887W  average rating is  3.94565217391
# The third similar product is  B00471400O  average rating is  4.92857142857
# -----------------------------------------------------------
# [[  9.94987437   9.94987437  10.39230485]]
# [[6314 4484  579]]
# Based on product reviews, for  B004WIUNBW  average rating is  3.78378378378
# The first similar product is  B0086VIA20  average rating is  4.35714285714
# The second similar product is  B005DEK9CC  average rating is  4.61538461538
# The third similar product is  B002RL8FIE  average rating is  4.65
# -----------------------------------------------------------
# [[ 1.73205081  1.73205081  1.73205081]]
# [[359  64 358]]
# Based on product reviews, for  B00H4HP24Q  average rating is  4.4
# The first similar product is  B002MQ962I  average rating is  3.8
# The second similar product is  B002FD0HU8  average rating is  4.57142857143
# The third similar product is  B002MPPYWK  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 3.31662479  3.46410162  3.46410162]]
# [[1312 1573 1428]]
# Based on product reviews, for  B005H58TKG  average rating is  3.8125
# The first similar product is  B00361EQR8  average rating is  5.0
# The second similar product is  B003AYEHXE  average rating is  4.5
# The third similar product is  B00380LVLG  average rating is  4.22222222222
# -----------------------------------------------------------
# [[ 2.44948974  2.64575131  2.64575131]]
# [[ 533 1964 1543]]
# Based on product reviews, for  B005SROBPA  average rating is  4.4
# The first similar product is  B002QO00XU  average rating is  4.83333333333
# The second similar product is  B003KJ31Z4  average rating is  4.6
# The third similar product is  B003ALLHLM  average rating is  3.89795918367
# -----------------------------------------------------------
# [[ 23.70653918  23.9582971   24.45403852]]
# [[1609 1721  738]]
# Based on product reviews, for  B00GBQ3K54  average rating is  4.87671232877
# The first similar product is  B003BHSXPS  average rating is  4.0625
# The second similar product is  B003D7L93O  average rating is  4.2
# The third similar product is  B002TSOEFS  average rating is  1.44444444444
# -----------------------------------------------------------
# [[ 6.78232998  6.78232998  7.14142843]]
# [[1119  110  645]]
# Based on product reviews, for  B0086VIA1Q  average rating is  4.56
# The first similar product is  B0030HKZ50  average rating is  4.4328358209
# The second similar product is  B002GOJL6C  average rating is  3.5
# The third similar product is  B002RXMGTG  average rating is  4.6
# -----------------------------------------------------------
# [[ 2.23606798  2.23606798  2.23606798]]
# [[5141 2176 2582]]
# Based on product reviews, for  B002E3BJQA  average rating is  4.6
# The first similar product is  B0064EOF6G  average rating is  3.66666666667
# The second similar product is  B003QY8BJE  average rating is  4.80769230769
# The third similar product is  B0040IAZ0S  average rating is  4.35294117647
# -----------------------------------------------------------
# [[ 11.53256259  12.24744871  13.82027496]]
# [[1669 2666 2463]]
# Based on product reviews, for  B0049MM85K  average rating is  4.1914893617
# The first similar product is  B003C54M9A  average rating is  4.5
# The second similar product is  B00424KNWA  average rating is  4.66666666667
# The third similar product is  B003XU8AMY  average rating is  4.22222222222
# -----------------------------------------------------------
# [[ 4.  4.  4.]]
# [[2030  325 1241]]
# Based on product reviews, for  B00FCEMHBO  average rating is  4.5625
# The first similar product is  B003LZQGN6  average rating is  4.52173913043
# The second similar product is  B002LMLN9W  average rating is  4.6
# The third similar product is  B0033WSV7Q  average rating is  4.4
# -----------------------------------------------------------
# [[ 10.29563014  13.11487705  13.82027496]]
# [[3139  295 2266]]
# Based on product reviews, for  B002XULC84  average rating is  3.95652173913
# The first similar product is  B004DTXHBS  average rating is  4.9
# The second similar product is  B002KT3ARO  average rating is  4.38461538462
# The third similar product is  B003U7FYD8  average rating is  4.57142857143
# -----------------------------------------------------------
# [[ 3.46410162  3.60555128  3.60555128]]
# [[5933 1409 5582]]
# Based on product reviews, for  B002Y27J9C  average rating is  5.0
# The first similar product is  B007PA6RQ4  average rating is  3.71428571429
# The second similar product is  B0037LGS96  average rating is  3.8
# The third similar product is  B0074O7Q7A  average rating is  4.44444444444
# -----------------------------------------------------------
# [[ 2.64575131  2.64575131  2.64575131]]
# [[2043  475  114]]
# Based on product reviews, for  B004ARVECC  average rating is  3.8
# The first similar product is  B003MOIC1A  average rating is  3.71428571429
# The second similar product is  B002PAR0EM  average rating is  2.42857142857
# The third similar product is  B002GTR902  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 3.31662479  3.60555128  3.60555128]]
# [[ 889 2858  194]]
# Based on product reviews, for  B00CX4CFRM  average rating is  4.4
# ...
# The second similar product is  B0040KOUI4  average rating is  3.16666666667
# The third similar product is  B002RL8FK2  average rating is  4.4696969697
# -----------------------------------------------------------
# [[ 6.32455532  6.92820323  7.        ]]
# [[1253  808 5605]]
# Based on product reviews, for  B00KO3EYLE  average rating is  4.94117647059
# The first similar product is  B00347ACH2  average rating is  4.52631578947
# The second similar product is  B002V40IS2  average rating is  4.7
# The third similar product is  B007636DIW  average rating is  4.0
# -----------------------------------------------------------
# [[ 4.47213595  4.47213595  4.47213595]]
# [[4995 3545 4428]]
# Based on product reviews, for  B00C2YM492  average rating is  4.64285714286
# The first similar product is  B005VOZ4B0  average rating is  3.2
# The second similar product is  B004O2I9JO  average rating is  4.55483870968
# The third similar product is  B005BTN6QA  average rating is  5.0
# -----------------------------------------------------------
# [[ 2.82842712  2.82842712  2.82842712]]
# [[910 358 740]]
# Based on product reviews, for  B00EE8GU3A  average rating is  5.0
# The first similar product is  B002WJHC58  average rating is  3.14285714286
# The second similar product is  B002MPPYWK  average rating is  4.33333333333
# The third similar product is  B002TUUZY0  average rating is  4.71428571429
# -----------------------------------------------------------
# [[ 6.164414    6.70820393  6.78232998]]
# [[ 306 4284 2581]]
# Based on product reviews, for  B008B9Y0EY  average rating is  4.44444444444
# The first similar product is  B002L5K40S  average rating is  4.0
# The second similar product is  B0056TA0NM  average rating is  4.3
# The third similar product is  B0040HM5F2  average rating is  4.85714285714
# -----------------------------------------------------------
# [[ 3.  3.  3.]]
# [[475 412 114]]
# Based on product reviews, for  B004CZYJLA  average rating is  4.55555555556
# The first similar product is  B002PAR0EM  average rating is  2.42857142857
# The second similar product is  B002NPCMJC  average rating is  4.56363636364
# The third similar product is  B002GTR902  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 11.44552314  11.53256259  12.80624847]]
# [[1008 5670 1789]]
# Based on product reviews, for  B00FF77IQC  average rating is  4.31578947368
# The first similar product is  B002Y4DBPQ  average rating is  3.88888888889
# The second similar product is  B0078KIJ6M  average rating is  3.85714285714
# The third similar product is  B003EOMVX8  average rating is  4.32142857143
# -----------------------------------------------------------
# [[ 3.46410162  3.60555128  3.60555128]]
# [[5190 1006 2673]]
# Based on product reviews, for  B0057QCGRM  average rating is  4.5
# The first similar product is  B0067NMAFC  average rating is  4.83333333333
# The second similar product is  B002Y49AR4  average rating is  4.2
# The third similar product is  B00424QR84  average rating is  5.0
# -----------------------------------------------------------
# [[ 2.82842712  3.          3.        ]]
# [[5141   40  391]]
# Based on product reviews, for  B003BKRMGG  average rating is  3.57142857143
# The first similar product is  B0064EOF6G  average rating is  3.66666666667
# The second similar product is  B002EIO6DI  average rating is  4.4
# The third similar product is  B002N616A2  average rating is  4.55555555556
# -----------------------------------------------------------
# [[ 8.60232527  8.66025404  8.77496439]]
# [[4927 3596 5455]]
# Based on product reviews, for  B008CENWK6  average rating is  3.0
# The first similar product is  B005R4YB9K  average rating is  4.625
# The second similar product is  B004PEGI26  average rating is  4.75
# The third similar product is  B006U431YW  average rating is  3.875
# -----------------------------------------------------------
# [[ 7.41619849  7.81024968  7.93725393]]
# [[4725 5155 1893]]
# Based on product reviews, for  B00COCNZ86  average rating is  4.61538461538
# The first similar product is  B005JE9F9E  average rating is  4.83333333333
# The second similar product is  B0064T0A8S  average rating is  4.16666666667
# The third similar product is  B003IA8ULA  average rating is  4.5
# -----------------------------------------------------------
# [[ 3.46410162  3.60555128  3.60555128]]
# [[4049 1342 1930]]
# Based on product reviews, for  B00C39C5B8  average rating is  2.81818181818
# The first similar product is  B004ZFTHJ6  average rating is  2.5
# The second similar product is  B0036F576I  average rating is  5.0
# The third similar product is  B003JI4Q50  average rating is  3.46153846154
# -----------------------------------------------------------
# [[ 3.          3.16227766  3.31662479]]
# [[3867 1909 3250]]
# Based on product reviews, for  B003UZWF7S  average rating is  4.33333333333
# The first similar product is  B004VB9Z7I  average rating is  4.88888888889
# The second similar product is  B003IP8BC8  average rating is  4.57971014493
# The third similar product is  B004GJVD1Q  average rating is  4.14285714286
# -----------------------------------------------------------
# [[ 3.          3.46410162  3.46410162]]
# [[2703 3609 2676]]
# Based on product reviews, for  B006CSQU0I  average rating is  4.4
# The first similar product is  B0042RPDYU  average rating is  4.14285714286
# The second similar product is  B004PTLN6M  average rating is  2.2
# The third similar product is  B00424UL5E  average rating is  4.28571428571
# -----------------------------------------------------------
# [[  9.11043358   9.53939201  10.29563014]]
# [[3676 1774 4407]]
# Based on product reviews, for  B00HQNEYCY  average rating is  4.87179487179
# The first similar product is  B004R67DMG  average rating is  3.9756097561
# The second similar product is  B003EA3VDQ  average rating is  4.57142857143
# The third similar product is  B005BFYQ4U  average rating is  2.8
# -----------------------------------------------------------
# [[ 11.3137085   11.74734012  11.83215957]]
# [[1615 2955  250]]
# Based on product reviews, for  B00EI4OM1M  average rating is  4.07843137255
# The first similar product is  B003BI2KJ2  average rating is  4.46153846154
# The second similar product is  B0049E52GU  average rating is  4.875
# The third similar product is  B002JVWZQU  average rating is  4.7
# -----------------------------------------------------------
# [[ 2.64575131  2.82842712  2.82842712]]
# [[5784  358  740]]
# Based on product reviews, for  B0042G80MS  average rating is  3.875
# The first similar product is  B007GGCLGW  average rating is  4.06666666667
# The second similar product is  B002MPPYWK  average rating is  4.33333333333
# The third similar product is  B002TUUZY0  average rating is  4.71428571429
# -----------------------------------------------------------
# [[ 10.72380529  11.22497216  11.22497216]]
# [[2008 5248 4216]]
# Based on product reviews, for  B0038QQ7RI  average rating is  4.575
# The first similar product is  B003LKU1KK  average rating is  4.33333333333
# The second similar product is  B006C6EM78  average rating is  4.75
# The third similar product is  B0054QSQ92  average rating is  4.54545454545
# -----------------------------------------------------------
# [[ 3.31662479  3.31662479  3.31662479]]
# [[3586 2530 3551]]
# Based on product reviews, for  B00FWNDE4O  average rating is  5.0
# The first similar product is  B004P3P2U6  average rating is  4.0
# The second similar product is  B003YZOGO4  average rating is  4.6835443038
# The third similar product is  B004O76DEC  average rating is  4.78260869565
# -----------------------------------------------------------
# [[ 2.82842712  3.          3.16227766]]
# [[1880 2505 6067]]
# Based on product reviews, for  B005LF5KGS  average rating is  4.22222222222
# The first similar product is  B003HUQIA6  average rating is  4.8
# The second similar product is  B003YP28G2  average rating is  4.33333333333
# The third similar product is  B007W94VH0  average rating is  4.72727272727
# -----------------------------------------------------------
# [[ 8.54400375  9.53939201  9.89949494]]
# [[3935  849 5386]]
# Based on product reviews, for  B00H2B4H2M  average rating is  4.22222222222
# The first similar product is  B004WNSZGC  average rating is  4.27272727273
# The second similar product is  B002VPE7JM  average rating is  4.8
# The third similar product is  B006OCW0A6  average rating is  4.2
# -----------------------------------------------------------
# [[ 4.58257569  4.79583152  4.79583152]]
# [[1241 5060 3472]]
# Based on product reviews, for  B003UWQR8Y  average rating is  4.48148148148
# The first similar product is  B0033WSV7Q  average rating is  4.4
# The second similar product is  B005YU8X6O  average rating is  4.375
# The third similar product is  B004MAOJEW  average rating is  3.4
# -----------------------------------------------------------
# [[ 2.82842712  2.82842712  2.82842712]]
# [[2217 1351 1724]]
# Based on product reviews, for  B002UF94OQ  average rating is  3.4
# The first similar product is  B003SZ4C1W  average rating is  3.73333333333
# The second similar product is  B0036QOP0G  average rating is  4.73333333333
# The third similar product is  B003D7LHI6  average rating is  3.2
# -----------------------------------------------------------
# [[ 3.16227766  3.31662479  3.31662479]]
# [[4040 4059 2851]]
# Based on product reviews, for  B0040ZONCW  average rating is  5.0
# The first similar product is  B004Z6MQIE  average rating is  4.2
# The second similar product is  B004ZN7W4A  average rating is  4.5
# The third similar product is  B00466WND6  average rating is  4.26086956522
# -----------------------------------------------------------
# [[ 3.87298335  3.87298335  4.        ]]
# [[3519 4042   16]]
# Based on product reviews, for  B006L7SNKU  average rating is  4.0
# The first similar product is  B004NPE3AG  average rating is  4.44444444444
# The second similar product is  B004ZBCT0E  average rating is  5.0
# The third similar product is  B002DYJ1C4  average rating is  4.49645390071
# -----------------------------------------------------------
# [[ 2.82842712  2.82842712  2.82842712]]
# [[5835 1872 5348]]
# Based on product reviews, for  B002N5N5DY  average rating is  2.33333333333
# The first similar product is  B007JL4JBO  average rating is  4.25
# The second similar product is  B003HFG07M  average rating is  4.7037037037
# The third similar product is  B006L8M91S  average rating is  4.2
# -----------------------------------------------------------
# [[ 2.  2.  2.]]
# [[3636  910  358]]
# Based on product reviews, for  B002SR9PPY  average rating is  4.4
# The first similar product is  B004QHDJNI  average rating is  4.44444444444
# The second similar product is  B002WJHC58  average rating is  3.14285714286
# The third similar product is  B002MPPYWK  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 4.24264069  4.69041576  4.69041576]]
# [[3981 6265 3697]]
# Based on product reviews, for  B0037UWO90  average rating is  4.5
# The first similar product is  B004XVNDL0  average rating is  4.63636363636
# The second similar product is  B0085A18A8  average rating is  4.35294117647
# The third similar product is  B004RE1MRU  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 2.64575131  3.31662479  3.31662479]]
# [[5621 4280 4508]]
# Based on product reviews, for  B00A3FSCCK  average rating is  4.57142857143
# The first similar product is  B0076P12W2  average rating is  4.78571428571
# The second similar product is  B0056IZVNM  average rating is  4.5
# The third similar product is  B005DQTUWA  average rating is  4.66666666667
# -----------------------------------------------------------
# [[ 5.09901951  5.38516481  5.47722558]]
# [[4253 5712 5831]]
# Based on product reviews, for  B008MJW18K  average rating is  2.9
# The first similar product is  B0055OUGUU  average rating is  3.72906403941
# The second similar product is  B007B6R608  average rating is  4.0
# The third similar product is  B007JJYVQY  average rating is  4.83333333333
# -----------------------------------------------------------
# [[ 2.23606798  2.23606798  2.23606798]]
# [[362  64 358]]
# Based on product reviews, for  B0037AEYAW  average rating is  4.6
# The first similar product is  B002MUAP2E  average rating is  3.8
# The second similar product is  B002FD0HU8  average rating is  4.57142857143
# The third similar product is  B002MPPYWK  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 4.24264069  4.47213595  4.47213595]]
# [[2646 1088 2305]]
# Based on product reviews, for  B005P6R57K  average rating is  4.45454545455
# The first similar product is  B0041T46HY  average rating is  3.91666666667
# The second similar product is  B002ZUQODA  average rating is  4.6
# The third similar product is  B003ULEJF8  average rating is  4.58139534884
# -----------------------------------------------------------
# [[ 4.69041576  4.89897949  5.        ]]
# [[1459  862 1392]]
# Based on product reviews, for  B00GJZ1SZ6  average rating is  2.88888888889
# The first similar product is  B0038O0YNS  average rating is  4.25
# The second similar product is  B002VWJYOS  average rating is  4.41379310345
# The third similar product is  B0037AXFVQ  average rating is  4.2
# -----------------------------------------------------------
# [[ 4.35889894  4.47213595  4.79583152]]
# [[4175 3959 2784]]
# Based on product reviews, for  B004A7VFHG  average rating is  4.30769230769
# The first similar product is  B00537HNZ0  average rating is  4.8
# The second similar product is  B004X8KSUC  average rating is  5.0
# The third similar product is  B0044F7KS2  average rating is  4.75
# -----------------------------------------------------------
# [[ 4.69041576  4.79583152  4.79583152]]
# [[1324 2920 1967]]
# Based on product reviews, for  B003C5F8FW  average rating is  4.33333333333
# The first similar product is  B0036B7ZQ2  average rating is  4.61904761905
# The second similar product is  B0047Y6I24  average rating is  4.8
# The third similar product is  B003KJXLAE  average rating is  2.6
# -----------------------------------------------------------
# [[ 2.64575131  2.64575131  2.64575131]]
# [[910 358  40]]
# Based on product reviews, for  B0047TP6D6  average rating is  4.5
# The first similar product is  B002WJHC58  average rating is  3.14285714286
# The second similar product is  B002MPPYWK  average rating is  4.33333333333
# The third similar product is  B002EIO6DI  average rating is  4.4
# -----------------------------------------------------------
# [[ 3.          3.31662479  3.31662479]]
# [[3712  603  358]]
# Based on product reviews, for  B003CNS5TU  average rating is  4.33333333333
# The first similar product is  B004RR1FF6  average rating is  4.83333333333
# The second similar product is  B002RSVTHQ  average rating is  4.31578947368
# The third similar product is  B002MPPYWK  average rating is  4.33333333333
# -----------------------------------------------------------
# [[ 2.44948974  2.64575131  2.82842712]]
# [[2084 3710 1573]]
# Based on product reviews, for  B00D2I8GJE  average rating is  4.6
# The first similar product is  B003NQWXJ4  average rating is  5.0
# The second similar product is  B004RQ4ACW  average rating is  4.0
# The third similar product is  B003AYEHXE  average rating is  4.5
# -----------------------------------------------------------
# [[ 16.79285562  17.77638883  18.13835715]]
# [[1589  214 5101]]
# Based on product reviews, for  B00BBSPMIU  average rating is  4.68115942029
# The first similar product is  B003B6RB98  average rating is  5.0
# The second similar product is  B002JINMOM  average rating is  3.94117647059
# The third similar product is  B006293ZPA  average rating is  4.5
# -----------------------------------------------------------
# [[ 8.54400375  9.          9.21954446]]
# [[1386 6080  992]]
# Based on product reviews, for  B003O1Y4C2  average rating is  4.06818181818
# The first similar product is  B00373NN2E  average rating is  4.44444444444
# The second similar product is  B007WSVIK4  average rating is  2.66666666667
# The third similar product is  B002Y26UXS  average rating is  4.15384615385
# -----------------------------------------------------------

# %%
from sklearn.metrics import confusion_matrix

# %%
chk=pd.DataFrame(data={'acc':np.zeros(50),'n':np.zeros(50)})

train_rating=train['overall'].astype(int)
test_rating=test['overall'].astype(int)

for i in range (1,50,2):

    knnclf = neighbors.KNeighborsClassifier(i, weights='distance',algorithm='ball_tree')
    knnclf.fit(train_array, train_rating)


    predctions = knnclf.predict(test_array)
    #print(knnpreds_test)

    #print("Classification Report ...")
    #print(classification_report(test_rating,predctions))

    #print("Confussion Matrix....")
    #print(confusion_matrix(test_rating,predctions))
    
    chk['n'][i]=i
    chk['acc'][i]=accuracy_score(test_rating, predctions)
    
    print("n_neighbors  ",i)
    print("Accuracy:    ",accuracy_score(test_rating, predctions))
    print("MSE:         ",mean_squared_error(test_rating, predctions))
    print("\n")
# Out:
# n_neighbors   1
# Accuracy:     0.56297365572
# MSE:          0.61241429087
#
#
# n_neighbors   3
# Accuracy:     0.581017683147
# MSE:          0.609166365933
#
#
# n_neighbors   5
# Accuracy:     0.617466618549
# MSE:          0.501623962468
#
#
# n_neighbors   7
# Accuracy:     0.639119451462
# MSE:          0.463731504872
#
#
# n_neighbors   9
# Accuracy:     0.650306748466
# MSE:          0.434861060989
#
#
# n_neighbors   11
# Accuracy:     0.657885239986
# MSE:          0.420786719596
#
#
# n_neighbors   13
# Accuracy:     0.673403103573
# MSE:          0.393720678455
#
#
# n_neighbors   15
# Accuracy:     0.688199206063
# MSE:          0.378202814868
#
#
# n_neighbors   17
# Accuracy:     0.692890653194
# MSE:          0.374594009383
#
#
# n_neighbors   19
# Accuracy:     0.694695055936
# MSE:          0.368459040058
#
#
# n_neighbors   21
# Accuracy:     0.702634428004
# MSE:          0.360158787441
#
#
# n_neighbors   23
# Accuracy:     0.700108264165
# MSE:          0.362684951281
#
#
# n_neighbors   25
# Accuracy:     0.703356189101
# MSE:          0.360158787441
#
#
# n_neighbors   27
# Accuracy:     0.709491158427
# MSE:          0.351497654276
#
#
# n_neighbors   29
# Accuracy:     0.709130277878
# MSE:          0.352941176471
#
#
# n_neighbors   31
# Accuracy:     0.710212919524
# MSE:          0.351858534825
#
#
# n_neighbors   33
# Accuracy:     0.711295561169
# MSE:          0.352580295922
#
#
# n_neighbors   35
# Accuracy:     0.709852038975
# MSE:          0.351497654276
#
#
# n_neighbors   37
# Accuracy:     0.712378202815
# MSE:          0.351136773728
#
#
# n_neighbors   39
# Accuracy:     0.712017322266
# MSE:          0.349332370985
#
#
# n_neighbors   41
# Accuracy:     0.712378202815
# MSE:          0.344640923854
#
#
# n_neighbors   43
# Accuracy:     0.710212919524
# MSE:          0.354384698665
#
#
# n_neighbors   45
# Accuracy:     0.712378202815
# MSE:          0.354384698665
#
#
# n_neighbors   47
# Accuracy:     0.712739083363
# MSE:          0.348610609888
#
#
# n_neighbors   49
# Accuracy:     0.712739083363
# MSE:          0.355106459762
